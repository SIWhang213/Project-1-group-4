# %% [markdown]
# # Oil Company Stock Analysis

# %% [markdown]
# ### Some questions

# %% [markdown]
# ### Summarizes the analysis

# %% [markdown]
# ### Draws correct coclusions or comparisons from the calculations

# %%
# Dependencies and Setup
import os
import csv
import requests
import json
import hvplot.pandas
import matplotlib.image as mpimg

import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# yahoo finance library
import yfinance as yf
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Pre-question : Why are we focus on 6 oil companies? (How to choose them.)
# - Make data frame of 30 major oil companies adding some informations from yahoo finace and geoapify.
# - Filter them only to companies in the United States and the United Kingdom.
#   (The United Kindom is included because some companies that have a strong impact on the U.S. oil industry are headquartered there.)
# - Sort them by gross profits and choose top 6 oil comapnies

# %%
csv_file_path_1 = 'Results/30_companies_info_total.csv'
oil_company_data_30 = pd.read_csv(csv_file_path_1)
#oil_company_data_30

# %%
csv_file_path_2 = 'Results/6_companies_info_total.csv'
oil_company_data_6 = pd.read_csv(csv_file_path_2)
oil_company_data_6
# Out:
#                      Company Name Ticker  \
# 0         Exxon Mobil Corporation    XOM
# 1             Chevron Corporation    CVX
# 2                       Shell plc   SHEL
# 3                       BP p.l.c.     BP
# 4                  ConocoPhillips    COP
# 5  Marathon Petroleum Corporation    MPC
#
#                                              Address  Full Time Employees  \
# 0  5959 Las Colinas Boulevard, Irving, TX, 75039-...              62000.0
# 1  6001 Bollinger Canyon Road, San Ramon, CA, 945...              43846.0
# 2  Shell Centre, London, None, SE1 7NA, United Ki...              91140.0
# 3  1 St James's Square, London, None, SW1Y 4PD, U...              67600.0
# 4  925 North Eldridge Parkway, Houston, TX, 77079...               9700.0
# 5  539 South Main Street, Findlay, OH, 45840-3229...              17800.0
#
#    Market Capitalization (Market Cap)  Enterprise Value (EV)  Total Revenue  \
# 0                        437288730624           460750585856   3.679770e+11
# 1                        297691217920           313186058240   2.146720e+11
# 2                        204385419264           246093201408   3.585890e+11
# 3                        104156094464           467766444032   2.275870e+11
# 4                        139774033920           150561669120   6.877500e+10
# 5                         61326598144            80990756864   1.575150e+11
#
#    Gross Profits    Total Debt   Latitude   Longitude
# 0   133715000000  4.149600e+10  32.890255  -96.949441
# 1    98886000000  2.151400e+10  37.758335 -121.959458
# 2    97308000000  8.436600e+10  51.463735   -0.021389
# 3    70171000000  6.069900e+10  51.507730   -0.134570
# 4    39598000000  1.644400e+10  29.783352  -95.617801
# 5    26565000000  2.856500e+10  41.036497  -83.650163

# %%
 saved_fig_path_1 = "Results/30_oil_companies_map.png"
saved_fig_path_2 = "Results/6_oil_companies_map.png"

# Display 30 major oil companies on the map
plt.figure(figsize=(16,10))
loaded_image = mpimg.imread(saved_fig_path_1)
plt.subplot(2,1,1)
plt.imshow(loaded_image)
plt.title('30 Major Oil Companies in the World')
plt.axis('off')  

# Display 6 selected oil companies on the map
loaded_image = mpimg.imread(saved_fig_path_2)
plt.subplot(2,1,2)
plt.imshow(loaded_image)
plt.title('6 selected oil companies in the United States and the United Kingdom')
plt.axis('off')  

#plt.subplots_adjust(wspace=4)  

plt.tight_layout()
plt.show()

# %% [markdown]
# ## How much does US gasolin prices affect the stock market in the US oil industry?
# - stock price from yahoo finance
# - gasoline price in the US from FRED (https://fred.stlouisfed.org/):  the average price of all unleaded regular gasoline
# - line regression and r-value between gasoline price and oil company's stock price
# ### Anaysis
# - Exxon Mobil Corporation (XOM), Chevron Corporation(CVX), ConocoPhillips(COP), Marathon Petroleum Corporation(MPC) have strong correlation with gasoline price.
# - Shell plc	(SHEL) and BP plc (BP) have weak correlation with gasoline price.
# - The apparent difference between the two groups is the position of the headquarter.
# ### Further research
# - Shell PLC (SHEL) is one of the most common oil companies in the United States. What are the other domestic factors affecting the stock price?

# %%
# Path to the saved image
image_path_1 = "Results/stock_price_oil_price.png"

# Display the image using matplotlib
plt.figure(figsize=(10,6))
loaded_image = mpimg.imread(image_path_1)
plt.imshow(loaded_image)
plt.axis('off')  
plt.show()

# %%
# Path to the saved image
image_path_2 = "Results/line_regression_stock_oil.png"

# Display the image using matplotlib
plt.figure(figsize=(12,8))

loaded_image = mpimg.imread(image_path_2)
plt.imshow(loaded_image)
plt.axis('off')  
plt.show()

# %% [markdown]
# ## How much does COVID-19 affect the stock market in the US oil industry?
# - covid-19 data from our world in data or WHO.
# ### Analysis
# - There is little correlation between oil companies' stock prices and new COVID-19 cases.
# ### Further research (thinking about why this analysis failed)
# - Check if the impact of COVID-19 does not appear immediately and there seems to be a time difference.
# - Are there any other factors that have affected the stock more strongly during the COVID-19 pandemic? (For example, Russian invasion of Ukraine.)

# %%
# Path to the saved image
image_path_4 = "Results/oil_psice_covid.png"
image_path_3 = "Results/covid_data.png"
# Display the image using matplotlib

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
loaded_image = mpimg.imread(image_path_3)
plt.imshow(loaded_image)
plt.axis('off')  

plt.subplot(2,1,2)
loaded_image = mpimg.imread(image_path_4)
plt.imshow(loaded_image)
plt.axis('off')  
plt.subplots_adjust(hspace=0.)  
plt.show()

# %%
# Path to the saved image
image_path_5 = "Results/line_regression_stock_covid.png"

# Display the image using matplotlib
plt.figure(figsize=(12,8))

loaded_image = mpimg.imread(image_path_5)
plt.imshow(loaded_image)
plt.axis('off')  
plt.show()

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, PyOilStockAnalysis.ipynb, uses Python script to 
 #      analyze the relationship during a three year period, December 2019 to December 2022,
 #      between 30 oil company stocks and a variety of measures to answer a number of 
 #      questions.
 #
 #      pip install yahoo_fin      
 #      pip install requests_html 
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     Group #4 Team
 #
 #******************************************************************************************/

import OilStockProjectConstants as constant
import OilStockProjectFunctions as function
import OilStockProjectSubRoutines as subroutine

import datetime
import pandas as pds
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy import stats

# Dependencies and Setup
import os
import csv
import requests
import json
import hvplot.pandas
import matplotlib.image as mpimg


# yahoo finance library
import yfinance as yf

# %% [markdown]
# # <br> **Section 2: Prepare the Data**

# %% [markdown]
# ### **Yahoo Finance API Full Ticker Download**

# %%
# This function takes a full list of stock tickers without duplicates
# from the Yahoo Finance API in the categories of S&P 500, DJIA, 
# and Other.
completeStockTickerList \
    = function \
        .ReturnCompleteStockList()

# %%
# This print statement gives a count of the tickers in the complete List.
print('There are {:,} tickers in the complete stock ticker List.' \
      .format(len(completeStockTickerList)))
# Out:
# There are 11,320 tickers in the complete stock ticker List.

# %% [markdown]
# ### **Oil Company Data Retrieval**

# %%
# This function returns a DataFrame of oil company tickers and their market 
# capitalization datafrom the original List (the process takes approximately 
# 45-60 minutes to complete.

#oilCompanyMarketCapUnprocessedDataFrame \
#    = function \
#        .ReturnDataFrameOfOilCompanies \
#            (completeStockTickerList)

#oilCompanyMarketCapUnprocessedDataFrame.to_csv(constant.CSV_FILE_PATH)

oilCompanyMarketCapUnprocessedDataFrame \
    = pds \
        .read_csv \
            (constant.CSV_FILE_PATH)

# %%
# This subroutine displays a count of the stock tickers and any redundancies 
# in the oil company market capitalization List.
subroutine \
    .DisplaySeriesCountAndRedundancies \
        (oilCompanyMarketCapUnprocessedDataFrame['Ticker'], \
         'the oil company market capitalization List')
# Out:
# There are now 217 stock tickers with 0 redundancies in the oil company market capitalization List.

# %% [markdown]
# ### **Oil Company Filter**

# %%
# This line of code drops rows that have n/a fields.
oilCompanyMarketCapDataFrame \
    = oilCompanyMarketCapUnprocessedDataFrame \
        .dropna()

# %%
# This subroutine displays a count of the stock tickers and any redundancies 
# in the oil company market capitalization List without n/a fields.
subroutine \
    .DisplaySeriesCountAndRedundancies \
        (oilCompanyMarketCapDataFrame['Ticker'], \
         'the oil company market capitalization List')
# Out:
# There are now 217 stock tickers with 0 redundancies in the oil company market capitalization List.

# %%
# This line of code tallys the number of companies in each industry and display the results.
print \
    (oilCompanyMarketCapDataFrame \
         .groupby \
             ('Industry') \
                 ['Company Name'] \
         .count())
# Out:
# Industry
# Oil & Gas Drilling                 7
# Oil & Gas E&P                     80
# Oil & Gas Equipment & Services    45
# Oil & Gas Integrated              15
# Oil & Gas Midstream               50
# Oil & Gas Refining & Marketing    20
# Name: Company Name, dtype: int64

# %%
# There is only one company in the Independent Oil & Gas industry, so the script removes 
# both that industry and its associated company.
updatedOilCompanyMarketCapDataFrame \
    = oilCompanyMarketCapDataFrame \
        [oilCompanyMarketCapDataFrame \
             ['Industry'] \
         != 'Independent Oil & Gas'].sort_values('Industry', ascending=True)

# %%
# These lines of code sort the DataFrame based on index then resets the index.
updatedOilCompanyMarketCapDataFrame \
    = updatedOilCompanyMarketCapDataFrame \
        .sort_index(axis=0)

updatedOilCompanyMarketCapDataFrame\
    .reset_index \
        (drop = True, 
         inplace = True)

# %%
# This subroutine displays a count of the stock tickers and any redundancies 
# in the oil company market capitalization List without the one industry with
# one company.
subroutine \
    .DisplaySeriesCountAndRedundancies \
        (updatedOilCompanyMarketCapDataFrame['Ticker'], \
         'the oil company market capitalization List')
# Out:
# There are now 217 stock tickers with 0 redundancies in the oil company market capitalization List.

# %% [markdown]
# ### **Display Oil Company Information**

# %%
# This function displays the first five lines of a formatted oil company 
# market capitalization DataFrame.
function. \
    DisplayFormattedMarketCapDataFrame \
        (updatedOilCompanyMarketCapDataFrame.head(),
         'Table 2.0: Oil Companies with Market Capitalization Metrics')
# Out:
# <style type="text/css">
# #T_ecd1e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_ecd1e_row0_col0, #T_ecd1e_row0_col1, #T_ecd1e_row0_col2, #T_ecd1e_row0_col3, #T_ecd1e_row0_col4, #T_ecd1e_row0_col5, #T_ecd1e_row0_col6, #T_ecd1e_row0_col7, #T_ecd1e_row1_col0, #T_ecd1e_row1_col1, #T_ecd1e_row1_col2, #T_ecd1e_row1_col3, #T_ecd1e_row1_col4, #T_ecd1e_row1_col5, #T_ecd1e_row1_col6, #T_ecd1e_row1_col7, #T_ecd1e_row2_col0, #T_ecd1e_row2_col1, #T_ecd1e_row2_col2, #T_ecd1e_row2_col3, #T_ecd1e_row2_col4, #T_ecd1e_row2_col5, #T_ecd1e_row2_col6, #T_ecd1e_row2_col7, #T_ecd1e_row3_col0, #T_ecd1e_row3_col1, #T_ecd1e_row3_col2, #T_ecd1e_row3_col3, #T_ecd1e_row3_col4, #T_ecd1e_row3_col5, #T_ecd1e_row3_col6, #T_ecd1e_row3_col7, #T_ecd1e_row4_col0, #T_ecd1e_row4_col1, #T_ecd1e_row4_col2, #T_ecd1e_row4_col3, #T_ecd1e_row4_col4, #T_ecd1e_row4_col5, #T_ecd1e_row4_col6, #T_ecd1e_row4_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_ecd1e">
#   <caption>Table 2.0: Oil Companies with Market Capitalization Metrics</caption>
#   <thead>
#     <tr>
#       <th id="T_ecd1e_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_ecd1e_level0_col1" class="col_heading level0 col1" >Ticker</th>
#       <th id="T_ecd1e_level0_col2" class="col_heading level0 col2" >Company Name</th>
#       <th id="T_ecd1e_level0_col3" class="col_heading level0 col3" >Industry</th>
#       <th id="T_ecd1e_level0_col4" class="col_heading level0 col4" >Market Cap (Min)</th>
#       <th id="T_ecd1e_level0_col5" class="col_heading level0 col5" >Market Cap (Max)</th>
#       <th id="T_ecd1e_level0_col6" class="col_heading level0 col6" >Market Cap (Mean)</th>
#       <th id="T_ecd1e_level0_col7" class="col_heading level0 col7" >Market Cap (Median)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ecd1e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ecd1e_row0_col1" class="data row0 col1" >AE</td>
#       <td id="T_ecd1e_row0_col2" class="data row0 col2" >Adams Resources & Energy, Inc.</td>
#       <td id="T_ecd1e_row0_col3" class="data row0 col3" >Oil & Gas Refining & Marketing</td>
#       <td id="T_ecd1e_row0_col4" class="data row0 col4" >$36,605,281.88</td>
#       <td id="T_ecd1e_row0_col5" class="data row0 col5" >$147,901,279.96</td>
#       <td id="T_ecd1e_row0_col6" class="data row0 col6" >$124,215,658.37</td>
#       <td id="T_ecd1e_row0_col7" class="data row0 col7" >$132,717,409.52</td>
#     </tr>
#     <tr>
#       <td id="T_ecd1e_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ecd1e_row1_col1" class="data row1 col1" >AM</td>
#       <td id="T_ecd1e_row1_col2" class="data row1 col2" >Antero Midstream Corporation</td>
#       <td id="T_ecd1e_row1_col3" class="data row1 col3" >Oil & Gas Midstream</td>
#       <td id="T_ecd1e_row1_col4" class="data row1 col4" >$615,416,177.28</td>
#       <td id="T_ecd1e_row1_col5" class="data row1 col5" >$2,308,098,163.95</td>
#       <td id="T_ecd1e_row1_col6" class="data row1 col6" >$1,334,721,889.33</td>
#       <td id="T_ecd1e_row1_col7" class="data row1 col7" >$1,352,087,609.62</td>
#     </tr>
#     <tr>
#       <td id="T_ecd1e_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_ecd1e_row2_col1" class="data row2 col1" >AMPY</td>
#       <td id="T_ecd1e_row2_col2" class="data row2 col2" >Amplify Energy Corp.</td>
#       <td id="T_ecd1e_row2_col3" class="data row2 col3" >Oil & Gas E&P</td>
#       <td id="T_ecd1e_row2_col4" class="data row2 col4" >$19,756,359.28</td>
#       <td id="T_ecd1e_row2_col5" class="data row2 col5" >$357,886,373.15</td>
#       <td id="T_ecd1e_row2_col6" class="data row2 col6" >$125,190,190.48</td>
#       <td id="T_ecd1e_row2_col7" class="data row2 col7" >$141,705,791.87</td>
#     </tr>
#     <tr>
#       <td id="T_ecd1e_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_ecd1e_row3_col1" class="data row3 col1" >AMTX</td>
#       <td id="T_ecd1e_row3_col2" class="data row3 col2" >Aemetis, Inc.</td>
#       <td id="T_ecd1e_row3_col3" class="data row3 col3" >Oil & Gas Refining & Marketing</td>
#       <td id="T_ecd1e_row3_col4" class="data row3 col4" >$12,552,562.13</td>
#       <td id="T_ecd1e_row3_col5" class="data row3 col5" >$30,073,765.84</td>
#       <td id="T_ecd1e_row3_col6" class="data row3 col6" >$18,986,014.03</td>
#       <td id="T_ecd1e_row3_col7" class="data row3 col7" >$17,980,279.31</td>
#     </tr>
#     <tr>
#       <td id="T_ecd1e_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_ecd1e_row4_col1" class="data row4 col1" >APA</td>
#       <td id="T_ecd1e_row4_col2" class="data row4 col2" >APA Corporation</td>
#       <td id="T_ecd1e_row4_col3" class="data row4 col3" >Oil & Gas E&P</td>
#       <td id="T_ecd1e_row4_col4" class="data row4 col4" >$1,390,683,856.94</td>
#       <td id="T_ecd1e_row4_col5" class="data row4 col5" >$12,003,805,528.28</td>
#       <td id="T_ecd1e_row4_col6" class="data row4 col6" >$6,279,797,688.22</td>
#       <td id="T_ecd1e_row4_col7" class="data row4 col7" >$3,894,152,356.05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <br> **Section 3: Oil Industry Market Capitalization Mean/Median Analysis**

# %% [markdown]
# ### **Mean/Median Statistical Calculations**

# %%
# This function returns the mean market capitalization by industry summary statistics 
# in a DataFrame.
meanMarketCapByIndustrySummaryStatisticsDataFrame \
    = function \
        .ReturnIndustryMarketCapStatisticsSummary \
            (updatedOilCompanyMarketCapDataFrame,
             'Market Cap (Mean)')

# %%
# This function returns the median market capitalization by industry summary statistics 
# in a DataFrame.
medianMarketCapByIndustrySummaryStatisticsDataFrame \
    = function \
        .ReturnIndustryMarketCapStatisticsSummary \
            (updatedOilCompanyMarketCapDataFrame,
             'Market Cap (Median)')

# %% [markdown]
# ### **Display Market Capitalization (Mean) Summary Statistics**

# %%
# This subroutine displays the mean market capitalization by industry summary statistics
# as a boxplot.
subroutine. \
    DisplaySummaryStatisticsBoxPlot \
        (updatedOilCompanyMarketCapDataFrame, \
         'Market Cap (Mean)', \
         'Figure 3.1: Market Capitalization (Mean) BoxPlot')

# %%
# This function displays the mean market capitalization by industry summary statistics DataFrame.
function \
    .DisplaySummaryStatistics \
        (meanMarketCapByIndustrySummaryStatisticsDataFrame, 
         'Table 3.1: Oil Industry Market (Mean) Cap Summary Statistics')
# Out:
# <style type="text/css">
# #T_1da70 caption {
#   color: black;
#   font-size: 16px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1da70_row0_col0, #T_1da70_row0_col1, #T_1da70_row0_col2, #T_1da70_row0_col3, #T_1da70_row0_col4, #T_1da70_row0_col5, #T_1da70_row0_col6, #T_1da70_row1_col0, #T_1da70_row1_col1, #T_1da70_row1_col2, #T_1da70_row1_col3, #T_1da70_row1_col4, #T_1da70_row1_col5, #T_1da70_row1_col6, #T_1da70_row1_col7, #T_1da70_row1_col8, #T_1da70_row2_col0, #T_1da70_row2_col1, #T_1da70_row2_col2, #T_1da70_row2_col3, #T_1da70_row2_col4, #T_1da70_row2_col5, #T_1da70_row2_col6, #T_1da70_row2_col7, #T_1da70_row2_col8, #T_1da70_row2_col9, #T_1da70_row2_col10, #T_1da70_row3_col0, #T_1da70_row3_col7, #T_1da70_row3_col9, #T_1da70_row3_col10, #T_1da70_row4_col0, #T_1da70_row4_col1, #T_1da70_row4_col2, #T_1da70_row4_col3, #T_1da70_row4_col4, #T_1da70_row4_col5, #T_1da70_row4_col6, #T_1da70_row4_col7, #T_1da70_row4_col8, #T_1da70_row4_col9, #T_1da70_row4_col10, #T_1da70_row5_col0, #T_1da70_row5_col8, #T_1da70_row5_col9, #T_1da70_row5_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_1da70_row0_col7, #T_1da70_row0_col9, #T_1da70_row0_col10, #T_1da70_row3_col1, #T_1da70_row3_col2, #T_1da70_row3_col3, #T_1da70_row3_col5, #T_1da70_row3_col6, #T_1da70_row3_col8, #T_1da70_row5_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_1da70_row0_col8, #T_1da70_row1_col9, #T_1da70_row1_col10, #T_1da70_row3_col4, #T_1da70_row5_col1, #T_1da70_row5_col2, #T_1da70_row5_col3, #T_1da70_row5_col5, #T_1da70_row5_col6, #T_1da70_row5_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_1da70">
#   <caption>Table 3.1: Oil Industry Market (Mean) Cap Summary Statistics</caption>
#   <thead>
#     <tr>
#       <th id="T_1da70_level0_col0" class="col_heading level0 col0" >Industry</th>
#       <th id="T_1da70_level0_col1" class="col_heading level0 col1" >Lower Quartile</th>
#       <th id="T_1da70_level0_col2" class="col_heading level0 col2" >Upper Quartile</th>
#       <th id="T_1da70_level0_col3" class="col_heading level0 col3" >Interquartile Range</th>
#       <th id="T_1da70_level0_col4" class="col_heading level0 col4" >Lower Boundary</th>
#       <th id="T_1da70_level0_col5" class="col_heading level0 col5" >Upper Boundary</th>
#       <th id="T_1da70_level0_col6" class="col_heading level0 col6" >Mean</th>
#       <th id="T_1da70_level0_col7" class="col_heading level0 col7" >Median</th>
#       <th id="T_1da70_level0_col8" class="col_heading level0 col8" >% Difference</th>
#       <th id="T_1da70_level0_col9" class="col_heading level0 col9" >Number of Companies</th>
#       <th id="T_1da70_level0_col10" class="col_heading level0 col10" >Number of Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1da70_row0_col0" class="data row0 col0" >Oil & Gas Drilling</td>
#       <td id="T_1da70_row0_col1" class="data row0 col1" >$367,425,484</td>
#       <td id="T_1da70_row0_col2" class="data row0 col2" >$6,530,006,917</td>
#       <td id="T_1da70_row0_col3" class="data row0 col3" >$6,162,581,433</td>
#       <td id="T_1da70_row0_col4" class="data row0 col4" >$-8,876,446,665</td>
#       <td id="T_1da70_row0_col5" class="data row0 col5" >$9,611,297,633</td>
#       <td id="T_1da70_row0_col6" class="data row0 col6" >$14,302,224,805</td>
#       <td id="T_1da70_row0_col7" class="data row0 col7" >$745,360,310</td>
#       <td id="T_1da70_row0_col8" class="data row0 col8" >0.95%</td>
#       <td id="T_1da70_row0_col9" class="data row0 col9" >7</td>
#       <td id="T_1da70_row0_col10" class="data row0 col10" >2</td>
#     </tr>
#     <tr>
#       <td id="T_1da70_row1_col0" class="data row1 col0" >Oil & Gas E&P</td>
#       <td id="T_1da70_row1_col1" class="data row1 col1" >$173,852,312</td>
#       <td id="T_1da70_row1_col2" class="data row1 col2" >$4,233,173,135</td>
#       <td id="T_1da70_row1_col3" class="data row1 col3" >$4,059,320,823</td>
#       <td id="T_1da70_row1_col4" class="data row1 col4" >$-5,915,128,923</td>
#       <td id="T_1da70_row1_col5" class="data row1 col5" >$6,262,833,547</td>
#       <td id="T_1da70_row1_col6" class="data row1 col6" >$7,152,546,733</td>
#       <td id="T_1da70_row1_col7" class="data row1 col7" >$1,081,413,406</td>
#       <td id="T_1da70_row1_col8" class="data row1 col8" >0.85%</td>
#       <td id="T_1da70_row1_col9" class="data row1 col9" >80</td>
#       <td id="T_1da70_row1_col10" class="data row1 col10" >19</td>
#     </tr>
#     <tr>
#       <td id="T_1da70_row2_col0" class="data row2 col0" >Oil & Gas Equipment & Services</td>
#       <td id="T_1da70_row2_col1" class="data row2 col1" >$273,563,287</td>
#       <td id="T_1da70_row2_col2" class="data row2 col2" >$3,125,020,894</td>
#       <td id="T_1da70_row2_col3" class="data row2 col3" >$2,851,457,608</td>
#       <td id="T_1da70_row2_col4" class="data row2 col4" >$-4,003,623,125</td>
#       <td id="T_1da70_row2_col5" class="data row2 col5" >$4,550,749,698</td>
#       <td id="T_1da70_row2_col6" class="data row2 col6" >$7,440,998,638</td>
#       <td id="T_1da70_row2_col7" class="data row2 col7" >$895,291,496</td>
#       <td id="T_1da70_row2_col8" class="data row2 col8" >0.88%</td>
#       <td id="T_1da70_row2_col9" class="data row2 col9" >45</td>
#       <td id="T_1da70_row2_col10" class="data row2 col10" >10</td>
#     </tr>
#     <tr>
#       <td id="T_1da70_row3_col0" class="data row3 col0" >Oil & Gas Integrated</td>
#       <td id="T_1da70_row3_col1" class="data row3 col1" >$144,201,093</td>
#       <td id="T_1da70_row3_col2" class="data row3 col2" >$1,425,608,284</td>
#       <td id="T_1da70_row3_col3" class="data row3 col3" >$1,281,407,191</td>
#       <td id="T_1da70_row3_col4" class="data row3 col4" >$-1,777,909,693</td>
#       <td id="T_1da70_row3_col5" class="data row3 col5" >$2,066,311,880</td>
#       <td id="T_1da70_row3_col6" class="data row3 col6" >$2,475,325,675</td>
#       <td id="T_1da70_row3_col7" class="data row3 col7" >$756,360,608</td>
#       <td id="T_1da70_row3_col8" class="data row3 col8" >0.69%</td>
#       <td id="T_1da70_row3_col9" class="data row3 col9" >15</td>
#       <td id="T_1da70_row3_col10" class="data row3 col10" >3</td>
#     </tr>
#     <tr>
#       <td id="T_1da70_row4_col0" class="data row4 col0" >Oil & Gas Midstream</td>
#       <td id="T_1da70_row4_col1" class="data row4 col1" >$259,036,617</td>
#       <td id="T_1da70_row4_col2" class="data row4 col2" >$2,354,678,758</td>
#       <td id="T_1da70_row4_col3" class="data row4 col3" >$2,095,642,142</td>
#       <td id="T_1da70_row4_col4" class="data row4 col4" >$-2,884,426,595</td>
#       <td id="T_1da70_row4_col5" class="data row4 col5" >$3,402,499,829</td>
#       <td id="T_1da70_row4_col6" class="data row4 col6" >$3,675,540,786</td>
#       <td id="T_1da70_row4_col7" class="data row4 col7" >$929,128,156</td>
#       <td id="T_1da70_row4_col8" class="data row4 col8" >0.75%</td>
#       <td id="T_1da70_row4_col9" class="data row4 col9" >50</td>
#       <td id="T_1da70_row4_col10" class="data row4 col10" >10</td>
#     </tr>
#     <tr>
#       <td id="T_1da70_row5_col0" class="data row5 col0" >Oil & Gas Refining & Marketing</td>
#       <td id="T_1da70_row5_col1" class="data row5 col1" >$782,616,815</td>
#       <td id="T_1da70_row5_col2" class="data row5 col2" >$22,622,948,797</td>
#       <td id="T_1da70_row5_col3" class="data row5 col3" >$21,840,331,982</td>
#       <td id="T_1da70_row5_col4" class="data row5 col4" >$-31,977,881,158</td>
#       <td id="T_1da70_row5_col5" class="data row5 col5" >$33,543,114,788</td>
#       <td id="T_1da70_row5_col6" class="data row5 col6" >$32,314,045,542</td>
#       <td id="T_1da70_row5_col7" class="data row5 col7" >$2,644,658,737</td>
#       <td id="T_1da70_row5_col8" class="data row5 col8" >0.92%</td>
#       <td id="T_1da70_row5_col9" class="data row5 col9" >20</td>
#       <td id="T_1da70_row5_col10" class="data row5 col10" >5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Display Market Capitalization (Median) Summary Statistics**

# %%
# This subroutine displays the median market capitalization by industry summary statistics
# as a boxplot.
subroutine. \
    DisplaySummaryStatisticsBoxPlot \
        (updatedOilCompanyMarketCapDataFrame, \
         'Market Cap (Median)', \
         'Figure 3.1: Market Capitalization (Median) BoxPlot')

# %%
# This function displays the median market capitalization by industry summary statistics DataFrame.
function \
    .DisplaySummaryStatistics \
        (medianMarketCapByIndustrySummaryStatisticsDataFrame, 
         'Table 3.2: Oil Industry Market Cap (Median) Summary Statistics')
# Out:
# <style type="text/css">
# #T_aeaec caption {
#   color: black;
#   font-size: 16px;
#   font-style: bold;
#   text-align: center;
# }
# #T_aeaec_row0_col0, #T_aeaec_row0_col2, #T_aeaec_row0_col3, #T_aeaec_row0_col4, #T_aeaec_row0_col5, #T_aeaec_row0_col6, #T_aeaec_row0_col7, #T_aeaec_row1_col0, #T_aeaec_row1_col1, #T_aeaec_row1_col2, #T_aeaec_row1_col3, #T_aeaec_row1_col4, #T_aeaec_row1_col5, #T_aeaec_row1_col6, #T_aeaec_row1_col7, #T_aeaec_row1_col8, #T_aeaec_row2_col0, #T_aeaec_row2_col1, #T_aeaec_row2_col2, #T_aeaec_row2_col3, #T_aeaec_row2_col4, #T_aeaec_row2_col5, #T_aeaec_row2_col6, #T_aeaec_row2_col7, #T_aeaec_row2_col8, #T_aeaec_row2_col9, #T_aeaec_row2_col10, #T_aeaec_row3_col0, #T_aeaec_row3_col1, #T_aeaec_row3_col9, #T_aeaec_row3_col10, #T_aeaec_row4_col0, #T_aeaec_row4_col1, #T_aeaec_row4_col2, #T_aeaec_row4_col3, #T_aeaec_row4_col4, #T_aeaec_row4_col5, #T_aeaec_row4_col6, #T_aeaec_row4_col7, #T_aeaec_row4_col8, #T_aeaec_row4_col9, #T_aeaec_row4_col10, #T_aeaec_row5_col0, #T_aeaec_row5_col8, #T_aeaec_row5_col9, #T_aeaec_row5_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_aeaec_row0_col1, #T_aeaec_row0_col9, #T_aeaec_row0_col10, #T_aeaec_row3_col2, #T_aeaec_row3_col3, #T_aeaec_row3_col5, #T_aeaec_row3_col6, #T_aeaec_row3_col7, #T_aeaec_row3_col8, #T_aeaec_row5_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_aeaec_row0_col8, #T_aeaec_row1_col9, #T_aeaec_row1_col10, #T_aeaec_row3_col4, #T_aeaec_row5_col1, #T_aeaec_row5_col2, #T_aeaec_row5_col3, #T_aeaec_row5_col5, #T_aeaec_row5_col6, #T_aeaec_row5_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_aeaec">
#   <caption>Table 3.2: Oil Industry Market Cap (Median) Summary Statistics</caption>
#   <thead>
#     <tr>
#       <th id="T_aeaec_level0_col0" class="col_heading level0 col0" >Industry</th>
#       <th id="T_aeaec_level0_col1" class="col_heading level0 col1" >Lower Quartile</th>
#       <th id="T_aeaec_level0_col2" class="col_heading level0 col2" >Upper Quartile</th>
#       <th id="T_aeaec_level0_col3" class="col_heading level0 col3" >Interquartile Range</th>
#       <th id="T_aeaec_level0_col4" class="col_heading level0 col4" >Lower Boundary</th>
#       <th id="T_aeaec_level0_col5" class="col_heading level0 col5" >Upper Boundary</th>
#       <th id="T_aeaec_level0_col6" class="col_heading level0 col6" >Mean</th>
#       <th id="T_aeaec_level0_col7" class="col_heading level0 col7" >Median</th>
#       <th id="T_aeaec_level0_col8" class="col_heading level0 col8" >% Difference</th>
#       <th id="T_aeaec_level0_col9" class="col_heading level0 col9" >Number of Companies</th>
#       <th id="T_aeaec_level0_col10" class="col_heading level0 col10" >Number of Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aeaec_row0_col0" class="data row0 col0" >Oil & Gas Drilling</td>
#       <td id="T_aeaec_row0_col1" class="data row0 col1" >$82,744,600</td>
#       <td id="T_aeaec_row0_col2" class="data row0 col2" >$6,632,966,287</td>
#       <td id="T_aeaec_row0_col3" class="data row0 col3" >$6,550,221,688</td>
#       <td id="T_aeaec_row0_col4" class="data row0 col4" >$-9,742,587,932</td>
#       <td id="T_aeaec_row0_col5" class="data row0 col5" >$9,908,077,131</td>
#       <td id="T_aeaec_row0_col6" class="data row0 col6" >$14,512,095,434</td>
#       <td id="T_aeaec_row0_col7" class="data row0 col7" >$939,020,490</td>
#       <td id="T_aeaec_row0_col8" class="data row0 col8" >0.94%</td>
#       <td id="T_aeaec_row0_col9" class="data row0 col9" >7</td>
#       <td id="T_aeaec_row0_col10" class="data row0 col10" >2</td>
#     </tr>
#     <tr>
#       <td id="T_aeaec_row1_col0" class="data row1 col0" >Oil & Gas E&P</td>
#       <td id="T_aeaec_row1_col1" class="data row1 col1" >$116,320,030</td>
#       <td id="T_aeaec_row1_col2" class="data row1 col2" >$3,784,176,987</td>
#       <td id="T_aeaec_row1_col3" class="data row1 col3" >$3,667,856,957</td>
#       <td id="T_aeaec_row1_col4" class="data row1 col4" >$-5,385,465,405</td>
#       <td id="T_aeaec_row1_col5" class="data row1 col5" >$5,618,105,465</td>
#       <td id="T_aeaec_row1_col6" class="data row1 col6" >$7,249,126,385</td>
#       <td id="T_aeaec_row1_col7" class="data row1 col7" >$908,236,463</td>
#       <td id="T_aeaec_row1_col8" class="data row1 col8" >0.87%</td>
#       <td id="T_aeaec_row1_col9" class="data row1 col9" >80</td>
#       <td id="T_aeaec_row1_col10" class="data row1 col10" >18</td>
#     </tr>
#     <tr>
#       <td id="T_aeaec_row2_col0" class="data row2 col0" >Oil & Gas Equipment & Services</td>
#       <td id="T_aeaec_row2_col1" class="data row2 col1" >$249,560,090</td>
#       <td id="T_aeaec_row2_col2" class="data row2 col2" >$3,697,792,275</td>
#       <td id="T_aeaec_row2_col3" class="data row2 col3" >$3,448,232,186</td>
#       <td id="T_aeaec_row2_col4" class="data row2 col4" >$-4,922,788,188</td>
#       <td id="T_aeaec_row2_col5" class="data row2 col5" >$5,421,908,368</td>
#       <td id="T_aeaec_row2_col6" class="data row2 col6" >$7,660,659,078</td>
#       <td id="T_aeaec_row2_col7" class="data row2 col7" >$907,496,714</td>
#       <td id="T_aeaec_row2_col8" class="data row2 col8" >0.88%</td>
#       <td id="T_aeaec_row2_col9" class="data row2 col9" >45</td>
#       <td id="T_aeaec_row2_col10" class="data row2 col10" >10</td>
#     </tr>
#     <tr>
#       <td id="T_aeaec_row3_col0" class="data row3 col0" >Oil & Gas Integrated</td>
#       <td id="T_aeaec_row3_col1" class="data row3 col1" >$153,872,488</td>
#       <td id="T_aeaec_row3_col2" class="data row3 col2" >$1,444,907,407</td>
#       <td id="T_aeaec_row3_col3" class="data row3 col3" >$1,291,034,919</td>
#       <td id="T_aeaec_row3_col4" class="data row3 col4" >$-1,782,679,891</td>
#       <td id="T_aeaec_row3_col5" class="data row3 col5" >$2,090,424,867</td>
#       <td id="T_aeaec_row3_col6" class="data row3 col6" >$2,432,552,869</td>
#       <td id="T_aeaec_row3_col7" class="data row3 col7" >$828,238,618</td>
#       <td id="T_aeaec_row3_col8" class="data row3 col8" >0.66%</td>
#       <td id="T_aeaec_row3_col9" class="data row3 col9" >15</td>
#       <td id="T_aeaec_row3_col10" class="data row3 col10" >3</td>
#     </tr>
#     <tr>
#       <td id="T_aeaec_row4_col0" class="data row4 col0" >Oil & Gas Midstream</td>
#       <td id="T_aeaec_row4_col1" class="data row4 col1" >$222,662,709</td>
#       <td id="T_aeaec_row4_col2" class="data row4 col2" >$2,477,910,366</td>
#       <td id="T_aeaec_row4_col3" class="data row4 col3" >$2,255,247,657</td>
#       <td id="T_aeaec_row4_col4" class="data row4 col4" >$-3,160,208,776</td>
#       <td id="T_aeaec_row4_col5" class="data row4 col5" >$3,605,534,195</td>
#       <td id="T_aeaec_row4_col6" class="data row4 col6" >$3,823,550,743</td>
#       <td id="T_aeaec_row4_col7" class="data row4 col7" >$918,705,467</td>
#       <td id="T_aeaec_row4_col8" class="data row4 col8" >0.76%</td>
#       <td id="T_aeaec_row4_col9" class="data row4 col9" >50</td>
#       <td id="T_aeaec_row4_col10" class="data row4 col10" >10</td>
#     </tr>
#     <tr>
#       <td id="T_aeaec_row5_col0" class="data row5 col0" >Oil & Gas Refining & Marketing</td>
#       <td id="T_aeaec_row5_col1" class="data row5 col1" >$762,162,139</td>
#       <td id="T_aeaec_row5_col2" class="data row5 col2" >$21,849,590,859</td>
#       <td id="T_aeaec_row5_col3" class="data row5 col3" >$21,087,428,720</td>
#       <td id="T_aeaec_row5_col4" class="data row5 col4" >$-30,868,980,942</td>
#       <td id="T_aeaec_row5_col5" class="data row5 col5" >$32,393,305,219</td>
#       <td id="T_aeaec_row5_col6" class="data row5 col6" >$31,319,216,773</td>
#       <td id="T_aeaec_row5_col7" class="data row5 col7" >$2,281,841,367</td>
#       <td id="T_aeaec_row5_col8" class="data row5 col8" >0.93%</td>
#       <td id="T_aeaec_row5_col9" class="data row5 col9" >20</td>
#       <td id="T_aeaec_row5_col10" class="data row5 col10" >5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <br> **Section 4: Oil Industry Stock Index**

# %% [markdown]
# ### **Oil Energy Sector Breakdown by Industry (Count vs. Market Capitalization)**

# %%
# These lines of code create a Series with the percentage of each industry by count.
industryCountSeries \
    = updatedOilCompanyMarketCapDataFrame \
        .groupby \
            ('Industry') \
                ['Ticker'] \
        .count()

totalCompaniesInSectorIntegerVariable \
    = industryCountSeries \
        .sum()

industryPercentSeries \
    =  (industryCountSeries \
            .astype(float) 
        / float \
            (totalCompaniesInSectorIntegerVariable)) \
       *100

# %%
# This function displays the proportion of each industry by the number of companies.
function. \
    DisplayOilIndustryPieChart \
        (industryPercentSeries, 
         'Figure 4.1: Oil Industry Share by Number Of Companies')

# %%
# These lines of code create a Series with the percentage of each industry by sum 
# of median market capitalization.
industrySumOfMedianMarketCapsSeries \
    = updatedOilCompanyMarketCapDataFrame \
        .groupby \
            ('Industry') \
                ['Market Cap (Median)'] \
        .sum()

totalMarketCapInSectorIntegerVariable \
    = industrySumOfMedianMarketCapsSeries \
        .sum()

totalMarketCapPerIndustryPercentSeries \
    = (industrySumOfMedianMarketCapsSeries \
           .astype(float) \
       / totalMarketCapInSectorIntegerVariable) \
      *100

# %%
# This function displays the proportion of each industry by the number of companies.
function. \
    DisplayOilIndustryPieChart \
        (totalMarketCapPerIndustryPercentSeries, 
         'Figure 4.2: Oil Industry Share by Market Capitalization')

# %% [markdown]
# ### **Oil Energy Sector Market Index from Leading Oil Companies**

# %%
# This function determines the top company in each industry by median market
# capitalization and its market index weight.
topOilCompaniesDataFrame \
    = function. \
        ReturnTopCompanyByIndustry \
            (updatedOilCompanyMarketCapDataFrame, \
             'Market Cap (Median)')

# %%
# This function displays the top six companies with their market index weights.
function. \
    DisplayFormattedLeadingOilCompanyIndexWeights \
        (topOilCompaniesDataFrame,
         'Figure 4.3: Top Oil Company Index Weights')
# Out:
# <style type="text/css">
# #T_3f83a caption {
#   color: black;
#   font-size: 16px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3f83a_row0_col0, #T_3f83a_row0_col1, #T_3f83a_row0_col2, #T_3f83a_row0_col3, #T_3f83a_row0_col4, #T_3f83a_row1_col0, #T_3f83a_row1_col1, #T_3f83a_row1_col2, #T_3f83a_row1_col3, #T_3f83a_row1_col4, #T_3f83a_row2_col0, #T_3f83a_row2_col1, #T_3f83a_row2_col2, #T_3f83a_row2_col3, #T_3f83a_row2_col4, #T_3f83a_row3_col0, #T_3f83a_row3_col1, #T_3f83a_row3_col2, #T_3f83a_row3_col4, #T_3f83a_row4_col0, #T_3f83a_row4_col1, #T_3f83a_row4_col2, #T_3f83a_row4_col3, #T_3f83a_row4_col4, #T_3f83a_row5_col0, #T_3f83a_row5_col1, #T_3f83a_row5_col2, #T_3f83a_row5_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_3f83a_row3_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_3f83a_row5_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_3f83a">
#   <caption>Figure 4.3: Top Oil Company Index Weights</caption>
#   <thead>
#     <tr>
#       <th id="T_3f83a_level0_col0" class="col_heading level0 col0" >Ticker</th>
#       <th id="T_3f83a_level0_col1" class="col_heading level0 col1" >Company Name</th>
#       <th id="T_3f83a_level0_col2" class="col_heading level0 col2" >Industry</th>
#       <th id="T_3f83a_level0_col3" class="col_heading level0 col3" >Market Cap (Median)</th>
#       <th id="T_3f83a_level0_col4" class="col_heading level0 col4" >Index Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3f83a_row0_col0" class="data row0 col0" >BORR</td>
#       <td id="T_3f83a_row0_col1" class="data row0 col1" >Borr Drilling Limited</td>
#       <td id="T_3f83a_row0_col2" class="data row0 col2" >Oil & Gas Drilling</td>
#       <td id="T_3f83a_row0_col3" class="data row0 col3" >$87,178,094,523</td>
#       <td id="T_3f83a_row0_col4" class="data row0 col4" >0.17</td>
#     </tr>
#     <tr>
#       <td id="T_3f83a_row1_col0" class="data row1 col0" >EGY</td>
#       <td id="T_3f83a_row1_col1" class="data row1 col1" >VAALCO Energy, Inc.</td>
#       <td id="T_3f83a_row1_col2" class="data row1 col2" >Oil & Gas E&P</td>
#       <td id="T_3f83a_row1_col3" class="data row1 col3" >$69,260,328,971</td>
#       <td id="T_3f83a_row1_col4" class="data row1 col4" >0.14</td>
#     </tr>
#     <tr>
#       <td id="T_3f83a_row2_col0" class="data row2 col0" >TS</td>
#       <td id="T_3f83a_row2_col1" class="data row2 col1" >Tenaris S.A.</td>
#       <td id="T_3f83a_row2_col2" class="data row2 col2" >Oil & Gas Equipment & Services</td>
#       <td id="T_3f83a_row2_col3" class="data row2 col3" >$98,295,637,058</td>
#       <td id="T_3f83a_row2_col4" class="data row2 col4" >0.19</td>
#     </tr>
#     <tr>
#       <td id="T_3f83a_row3_col0" class="data row3 col0" >E</td>
#       <td id="T_3f83a_row3_col1" class="data row3 col1" >Eni S.p.A.</td>
#       <td id="T_3f83a_row3_col2" class="data row3 col2" >Oil & Gas Integrated</td>
#       <td id="T_3f83a_row3_col3" class="data row3 col3" >$24,072,905,925</td>
#       <td id="T_3f83a_row3_col4" class="data row3 col4" >0.05</td>
#     </tr>
#     <tr>
#       <td id="T_3f83a_row4_col0" class="data row4 col0" >TRMD</td>
#       <td id="T_3f83a_row4_col1" class="data row4 col1" >TORM plc</td>
#       <td id="T_3f83a_row4_col2" class="data row4 col2" >Oil & Gas Midstream</td>
#       <td id="T_3f83a_row4_col3" class="data row4 col3" >$44,104,612,153</td>
#       <td id="T_3f83a_row4_col4" class="data row4 col4" >0.09</td>
#     </tr>
#     <tr>
#       <td id="T_3f83a_row5_col0" class="data row5 col0" >WKC</td>
#       <td id="T_3f83a_row5_col1" class="data row5 col1" >World Kinect Corporation</td>
#       <td id="T_3f83a_row5_col2" class="data row5 col2" >Oil & Gas Refining & Marketing</td>
#       <td id="T_3f83a_row5_col3" class="data row5 col3" >$188,960,553,552</td>
#       <td id="T_3f83a_row5_col4" class="data row5 col4" >0.37</td>
#     </tr>
#   </tbody>
# </table>

# %%
# This function creates a Series containing prices for an oil energy sector market 
# index using historical oil company stock prices during the period in question 
# and the weights from median market capitalizations.
oilMarketIndexByTopCompaniesSeries \
    = function \
        .ReturnOilSectorMarketIndexSeries \
            (topOilCompaniesDataFrame['Ticker'] \
                .tolist(), \
             topOilCompaniesDataFrame['Index Weight'] \
                .tolist())
# Out:
# Begin calculating oil company stock index Series...
#
# The calculation of the oil company stock index Series is complete.

# %%
# This subroutine displays the oil energy sector market index based on median market 
# capitalization from the top companies.
subroutine. \
    DisplayOneLineGraph \
    (oilMarketIndexByTopCompaniesSeries,
     'red',
     'Figure 4.3: Oil Energy Sector Market Index from Top Companies')

# %% [markdown]
# ### **Oil Energy Sector Market Index from All Oil Companies**

# %%
# These lines of code create index weights for all the companies in the oil 
# energy sector.
totalMedianMarketCapForSectorIntegerVariable \
    = updatedOilCompanyMarketCapDataFrame \
         ['Market Cap (Median)'] \
            .sum()

companyIndexWeightsSeries \
    = (updatedOilCompanyMarketCapDataFrame \
         ['Market Cap (Median)'] \
       / totalMedianMarketCapForSectorIntegerVariable)

# %%
# This function creates a Series containing index prices for the Oil Energy 
# Sector using historical oil company stock prices per day during the period 
# in question and the weights from median market capitalizations.
oilMarketIndexByAllCompaniesSeries \
    = function \
        .ReturnOilSectorMarketIndexSeries \
            (updatedOilCompanyMarketCapDataFrame['Ticker'] \
                 .unique() \
                 .tolist(), \
                 companyIndexWeightsSeries.tolist())
# Out:
# Begin calculating oil company stock index Series...
#
# The calculation of the oil company stock index Series is complete.

# %%
# This function displays the oil energy sector market index based on median market 
# capitalization from all the oil companies.
oilMarketIndexByAllCompaniesSeries \
    .rename \
        ('All Companies', 
         inplace = True)

subroutine. \
    DisplayOneLineGraph \
    (oilMarketIndexByAllCompaniesSeries,
     'blue',
     'Figure 4.4: Oil Energy Sector Market Index from All Companies')

# %% [markdown]
# ### **Top Companies vs. All Companies in the Oil Energy Sector**

# %%
# These lines of code display both oil energy sector indices.
frameDictionary \
        = {'Top Companies': 
               oilMarketIndexByTopCompaniesSeries, 
           'All Companies': 
               oilMarketIndexByAllCompaniesSeries}

colorDictionary \
    = { 'red', 
        'blue'}


subroutine. \
    DisplayLinesGraph \
        (frameDictionary,
         colorDictionary,
         'Figure 4.5: Oil Energy Sector Market Index Comparison')

# %% [markdown]
# ### **Top Companies vs. All Companies vs. the S&P 500**

# %%
# This function creates a Series containing prices for a the S&P 500.
sp500Series \
    = function. \
        ReturnHistoricalPricesSeries('^GSPC')

sp500Series.to_csv('./Resources/newCOVID.csv')

# %%
# These functions convert the Series values from prices to percent changes
oilMarketPercentTopSeries \
    = function \
        .ConvertValuesToPercentChange \
            (oilMarketIndexByTopCompaniesSeries)

oilMarketPercentAllSeries \
    = function \
        .ConvertValuesToPercentChange \
            (oilMarketIndexByAllCompaniesSeries)

sp500Series \
    .rename \
        ('All Companies', 
         inplace = True)

sp500PercentSeries \
    = function \
        .ConvertValuesToPercentChange \
            (sp500Series)

# %%
# These lines of code display the percent changes in the two oil energy sector indices
# with the S&P 500.
frameDictionary \
        = {'Top Companies': 
                oilMarketPercentTopSeries, 
           'All Companies': 
                oilMarketPercentAllSeries,
           'S&P 500':
                sp500PercentSeries}

colorDictionary \
    = { 'red', 
        'blue',
        'green'}


subroutine. \
    DisplayLinesGraph \
        (frameDictionary,
         colorDictionary,
         'Figure 4.6: Oil Energy Sector Market Indices with S&P 500 (% Change)',
         True)

# %%
# This subroutine calculates a regression line through the scatter plot and displays both
# for top oil companies vs. the S&P 500.
subroutine \
    .DisplayScatterPlot \
        (oilMarketPercentTopSeries, \
         sp500PercentSeries, 
         'Figure 4.7: Top Companies vs. S&P 500 (% Change)')
# Out:
# equation:             3            2
# 4.241e-05 x - 0.004336 x + 0.2946 x + 0.06659
#
# r-value:      0.57977
# r-squared:    0.33613
# correlation:  0.57564

# %%
# This subroutine calculates a regression line through the scatter plot and displays both
# for all oil companies vs. the S&P 500.
subroutine \
    .DisplayScatterPlot \
        (oilMarketPercentAllSeries, \
         sp500PercentSeries, 
         'Figure 4.8: All Companies vs. S&P 500 (% Change)')
# Out:
# equation:             3            2
# 0.0003058 x - 0.001828 x + 0.3482 x + 0.02109
#
# r-value:      0.64344
# r-squared:    0.41402
# correlation:  0.63962

# %%
# This subroutine calculates a regression line through the scatter plot and displays both
# for all oil companies vs. the S&P 500.
subroutine \
    .DisplayScatterPlot \
        (oilMarketPercentAllSeries, \
         oilMarketPercentTopSeries, 
         'Figure 4.9: All Companies vs. Top Companies (% Change)')
# Out:
# equation:             3            2
# 7.086e-05 x + 0.007377 x + 1.012 x - 0.1118
#
# r-value:      0.89597
# r-squared:    0.80276
# correlation:  0.89480

# %% [markdown]
# # <br> **Section 5: Analysis of the Effects of Various Factors on the Oil Industry**

# %% [markdown]
# ### **Data Acquisition**

# %%
# This function downloads prices for crude oil.
crudeOilPricesSeries \
    = function \
        .ReturnHistoricalPricesSeries('CL=F')

# %%
# This function downloads prices for gold.
goldPricesSeries \
    = function \
        .ReturnHistoricalPricesSeries('GC=F')

# %%
# This function downloads prices for 10-Year Bonds.
tenYearBondsPricesSeries \
    = function \
        .ReturnHistoricalPricesSeries('^TNX')

# %%
# This function downloads prices for Bitcoin.
bitcoinSeries \
    = function \
        .ReturnHistoricalPricesSeries('BTC-USD')

# %%
# This function downloads new case numbers for COVID.
covidNewCasesSeries \
    = function \
        .ReturnCovidNewCasesSeries()

# %%
# This function downloads new death numbers for COVID.
covidNewDeathsSeries \
    = function \
        .ReturnCovidNewDeathsSeries()

# %% [markdown]
# ### **Data Conversion**

# %%
covidNewCasesPercentSeries \
    = function \
        .ConvertValuesToPercentChange \
            (covidNewCasesSeries)

covidNewDeathsPercentSeries \
    = function \
        .ConvertValuesToPercentChange \
            (covidNewDeathsSeries)

crudeOilPricesPercentSeries \
    = function \
        .ConvertValuesToPercentChange \
            (crudeOilPricesSeries)

tenYearBondsPricesPercentSeries \
    = function \
        .ConvertValuesToPercentChange \
            (tenYearBondsPricesSeries)

bitcoinPercentSeries \
    = function \
        .ConvertValuesToPercentChange \
            (bitcoinSeries)

goldPricesPercentSeries \
    = function \
        .ConvertValuesToPercentChange \
            (goldPricesSeries)

# %% [markdown]
# ## **Section 5.1: Covid Cases**

# %%
# This subroutine displays a two stacked subplots of Covid cases and the oil stock index.
covidNewCasesSeries \
    .rename \
        ('Covid Cases', 
          inplace \
                = True)

oilMarketIndexByTopCompaniesSeries \
    .rename \
        ('Oil Stock Index', 
         inplace \
             = True)

subroutine \
    .DisplayTwoSubPlots \
        (covidNewCasesSeries, 
         oilMarketIndexByTopCompaniesSeries, 
         'Figure 5.1: New Covid Cases and Top Oil Company Stock Index')

# %%
# This subroutine displays a two stacked subplots of percent changes in Covid cases 
# and the oil stock index.
covidNewCasesPercentSeries \
    .rename \
        ('Covid Cases', 
         inplace \
             = True)

oilMarketPercentTopSeries \
    .rename \
        ('Oil Stock Index', 
         inplace \
             = True)

subroutine \
    .DisplayTwoSubPlots \
        (covidNewCasesPercentSeries, 
         oilMarketPercentTopSeries, 
         'Figure 5.2: New Covid Cases and Top Oil Company Stock Index (% Change)')

# %%
# This subroutine calculates a regression line through the scatter plot and displays
# the relationship between the top oil companies vs. the new covid cases.
subroutine \
    .DisplayScatterPlot \
        (oilMarketIndexByTopCompaniesSeries,
         covidNewCasesSeries,
         'Figure 5.3: New Covid Cases vs. Top Oil Company Stock Index')
# Out:
# equation:         3             2
# 281.1 x - 1.729e+04 x + 3.33e+05 x - 1.933e+06
#
# r-value:      0.27387
# r-squared:    0.07500
# correlation:  nan

# %%
# This subroutine calculates a regression line through the scatter plot and displays
# the relationship between the top oil companies vs. the new covid cases.
subroutine \
    .DisplayScatterPlot \
        (covidNewCasesPercentSeries, 
         oilMarketPercentTopSeries, 
         'Figure 5.4: New Covid Cases vs. Top Oil Company Stock Index')
# Out:
# equation:             3             2
# 2.337e-08 x - 6.563e-06 x - 0.001676 x + 0.05819
#
# r-value:      0.03802
# r-squared:    0.00145
# correlation:  nan

# %%
# This function displays the oil energy sector market index based on median market 
# capitalization from all the oil companies.
crudeOilPricesSeries \
    .rename \
        ('Crude Oil Prices', 
         inplace = True)

subroutine. \
    DisplayOneLineGraph \
    (crudeOilPricesSeries,
     'blue',
     'Figure 5.5: Crude Oil Prices per Barrel')

# %%
# This function displays the oil energy sector market index based on median market 
# capitalization from all the oil companies.
crudeOilPricesSeries \
    .rename \
        ('Crude Oil Prices', 
         inplace = True)

subroutine. \
    DisplayOneLineGraph \
    (crudeOilPricesPercentSeries,
     'blue',
     'Figure 5.6: Crude Oil Prices per Barrel (% Change)')

# %%
# This subroutine calculates a regression line through the scatter plot and displays
# the relationship between the top oil companies vs. the new covid cases.
subroutine \
    .DisplayScatterPlot \
        (oilMarketIndexByTopCompaniesSeries,
         crudeOilPricesSeries,
         'Figure 5.6: Crude Oil Prices vs. Top Oil Company Stock Index')
# Out:
# equation:           3         2
# -0.1298 x + 5.781 x - 76.78 x + 347.7
#
# r-value:      0.75697
# r-squared:    0.57300
# correlation:  0.64461

# %%
# This subroutine calculates a regression line through the scatter plot and displays
# the relationship between the top oil companies vs. the new covid cases.
subroutine \
    .DisplayScatterPlot \
        (crudeOilPricesSeries,
         covidNewCasesSeries,
         'Figure 5.7: Crude Oil Prices vs. New Covid Cases')
# Out:
# equation:           3         2
# -0.3121 x + 36.81 x + 488.5 x - 2335
#
# r-value:      0.21240
# r-squared:    0.04511
# correlation:  nan

# %% [markdown]
# # Relationship Between Oil Consumption and Stock Price

# %%
image_path_6 = "Oil vs Stock/Images/oil_df.png"
plt.figure(figsize=(10,6))
loaded_image = mpimg.imread(image_path_6)
plt.imshow(loaded_image)
plt.title("Total U.S. Product Supplied of Crude Oil and Petroleum Products (Thousand Barrels)")
plt.axis('off')  
plt.show()

# %%
image_path_7 = "Oil vs Stock/Images/oil_trend.png"
plt.figure(figsize=(15,10))
loaded_image = mpimg.imread(image_path_7)
plt.imshow(loaded_image)
plt.title('Oil Consumption Trend')
plt.axis('off')  
plt.show()

# %%
image_path_8 = "Oil vs Stock/Images/xom_scatter.png"
image_path_9 = "Oil vs Stock/Images/cvx_scatter.png"
image_path_10 = "Oil vs Stock/Images/cop_scatter.png"
image_path_11 = "Oil vs Stock/Images/mpc_scatter.png"

plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
loaded_image = mpimg.imread(image_path_8)
plt.imshow(loaded_image)
plt.title('r-value: 0.55')
plt.axis('off')  

plt.subplot(2,2,2)
loaded_image = mpimg.imread(image_path_9)
plt.imshow(loaded_image)
plt.title('r-value: 0.50')
plt.axis('off') 

plt.subplot(2,2,3)
loaded_image = mpimg.imread(image_path_10)
plt.imshow(loaded_image)
plt.title('r-value: 0.47')
plt.axis('off') 

plt.subplot(2,2,4)
loaded_image = mpimg.imread(image_path_11)
plt.imshow(loaded_image)
plt.title('r-value: 0.51')
plt.axis('off') 
plt.tight_layout()
plt.show()
