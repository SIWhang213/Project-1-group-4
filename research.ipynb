# %%
# Import packages
import requests
import json
import pandas as pd
import yfinance as yf

# %%
companyList \
    = ["XOM",  # ExxonMobil
       "CVX",  # Chevron
       "SHEL", # Shell
       "COP",  # ConocoPhillips
       "MRO",  # Marathon 
       "BP"]   # BP
 

xom = yf.Ticker("SHEL")
print(xom)
# Out:
# yfinance.Ticker object <SHEL>

# %%
#xom.history(period="max").tail()
for companyName in companyList:
    companyDataFrame = yf.download(companyName, start="2017-08-01", end="2023-08-01")
    print(companyName)
    print(companyDataFrame['Close'])
    
    
data = yf.download("XOM CVX SHEL COP MRO BP", start="2020-01-01", end="2020-06-01")
data['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# XOM
# Date
# 2017-08-01     80.169998
# 2017-08-02     80.599998
# 2017-08-03     80.489998
# 2017-08-04     80.209999
# 2017-08-07     80.160004
#                  ...
# 2023-07-25    105.680000
# 2023-07-26    105.089996
# 2023-07-27    105.419998
# 2023-07-28    104.160004
# 2023-07-31    107.239998
# Name: Close, Length: 1509, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# CVX
# Date
# 2017-08-01    110.779999
# 2017-08-02    110.459999
# 2017-08-03    109.430000
# 2017-08-04    110.110001
# 2017-08-07    109.779999
#                  ...
# 2023-07-25    162.559998
# 2023-07-26    161.339996
# 2023-07-27    159.660004
# 2023-07-28    158.869995
# 2023-07-31    163.660004
# Name: Close, Length: 1509, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# SHEL
# Date
# 2017-08-01    56.799999
# 2017-08-02    57.380001
# ...

# %%
data['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data = yf.download("^GSPC", start="2020-01-01", end="2020-06-01")
data['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2020-01-02    3257.850098
# 2020-01-03    3234.850098
# 2020-01-06    3246.280029
# 2020-01-07    3237.179932
# 2020-01-08    3253.050049
#                  ...
# 2020-05-22    2955.449951
# 2020-05-26    2991.770020
# 2020-05-27    3036.129883
# 2020-05-28    3029.729980
# 2020-05-29    3044.310059
# Name: Close, Length: 103, dtype: float64

# %%
data['Close'].plot()
# Out:
# <Axes: xlabel='Date'>
