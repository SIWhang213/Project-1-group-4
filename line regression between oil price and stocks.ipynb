# %%
# Import packages
import requests
import json
import hvplot.pandas
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
# Import the API key
from config import geoapify_key

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## 30 primary oil companies (from yahoo finance)

# %%
# Replace 'oil_company_list.csv' with your actual CSV file path
csv_file_path_2 = 'Resources/30_oil_companies.csv'

oil_company_list_data = pd.read_csv(csv_file_path_2)
oil_company_list_data
# Out:
#    Symbol                          Company Name  Last Price Change % Change  \
# 0     XOM               Exxon Mobil Corporation      110.12   0.56    0.51%
# 1     CVX                   Chevron Corporation      160.83   0.97    0.61%
# 2    SHEL                             Shell plc       62.32   0.46    0.75%
# 3     TTE                      TotalEnergies SE       63.32   0.78    1.25%
# 4     COP                        ConocoPhillips      115.83  -0.61   -0.52%
# 5      BP                             BP p.l.c.       37.08    0.1    0.26%
# 6    EQNR                           Equinor ASA       31.71  -0.84   -2.58%
# 7     PBR  Petróleo Brasileiro S.A. - Petrobras       13.68   0.08    0.59%
# 8   PBR-A  Petróleo Brasileiro S.A. - Petrobras       12.54   0.13    1.05%
# 9     SLB                  Schlumberger Limited       58.92  -0.59   -0.99%
# 10    EOG                   EOG Resources, Inc.      131.05   0.24    0.18%
# 11    ENB                         Enbridge Inc.       36.45  -0.04   -0.11%
# 12    CNQ    Canadian Natural Resources Limited       61.50   0.19    0.31%
# 13    MPC        Marathon Petroleum Corporation      145.28   1.23    0.85%
# 14    EPD     Enterprise Products Partners L.P.       26.64      -        -
# 15    OXY      Occidental Petroleum Corporation       63.73  -0.08   -0.13%
# 16    PXD     Pioneer Natural Resources Company      235.91  -0.68   -0.29%
# 17    PSX                           Phillips 66      114.67   0.25    0.22%
# 18      E                            Eni S.p.A.       30.97   0.25    0.81%
# 19    VLO             Valero Energy Corporation      134.86   0.91    0.68%
# 20    HES                      Hess Corporation      156.57   0.17    0.11%
# 21    WDS             Woodside Energy Group Ltd       25.19   0.07    0.28%
# 22    WMB          The Williams Companies, Inc.       35.06   -0.2   -0.57%
# 23     SU                    Suncor Energy Inc.       31.56  -0.16   -0.50%
# 24     ET                    Energy Transfer LP       13.07   0.09    0.69%
# 25    LNG                 Cheniere Energy, Inc.      166.90  -0.53   -0.32%
# 26    KMI                   Kinder Morgan, Inc.       17.54  -0.01   -0.06%
# 27    CVE                   Cenovus Energy Inc.       19.41   0.05    0.26%
# 28    HAL                   Halliburton Company       40.36   -0.1   -0.25%
# 29    TRP                 TC Energy Corporation       36.30  -0.12   -0.33%
#
#     Market Time   Volume Avg Vol (3 month) Market Cap
# 0   4:03 PM EDT   15.79M            15.82M    445.21B
# 1   4:03 PM EDT    8.64M             7.95M    300.66B
# 2   4:00 PM EDT    3.75M             4.61M    209.05B
# 3   4:00 PM EDT    2.03M             1.36M    153.50B
# 4   4:00 PM EDT    3.55M             5.50M    140.16B
# 5   4:00 PM EDT    7.72M             7.61M    107.07B
# 6   4:00 PM EDT    4.18M             2.94M     98.66B
# 7   4:00 PM EDT   14.71M            20.94M     89.22B
# 8   4:00 PM EDT    7.89M             9.10M     87.50B
# 9   4:00 PM EDT    8.28M            10.22M     83.74B
# 10  4:00 PM EDT    2.34M             3.37M     76.65B
# 11  4:00 PM EDT    3.92M             3.84M     73.80B
# 12  4:00 PM EDT    1.74M             1.87M     67.13B
# 13  4:00 PM EDT    3.59M             3.49M     62.47B
# 14  4:00 PM EDT    2.96M             4.35M     57.93B
# 15  4:00 PM EDT    7.60M            10.17M     56.83B
# 16  4:00 PM EDT    1.48M             1.84M     55.14B
# 17  4:00 PM EDT    2.57M             3.20M     52.62B
# 18  4:00 PM EDT  209.38k           226.71k     51.22B
# 19  4:00 PM EDT    3.74M             3.97M     48.75B
# 20  4:00 PM EDT    1.00M             1.72M     48.08B
# 21  4:00 PM EDT  385.85k           362.86k     47.83B
# 22  4:00 PM EDT    5.69M             7.45M     42.71B
# 23  4:00 PM EDT    5.09M             4.37M     41.33B
# 24  4:00 PM EDT   16.61M            10.27M     41.06B
# 25  4:00 PM EDT    1.60M             1.56M     40.64B
# 26  4:00 PM EDT   12.57M            13.28M     39.08B
# 27  4:00 PM EDT    9.15M             6.72M     36.87B
# 28  4:00 PM EDT    6.92M             9.31M     36.41B
# 29  4:00 PM EDT    1.59M             2.61M     36.34B

# %%
# Collect some data of the oil compnanies using yfinance 
ticker_symbols = oil_company_list_data["Symbol"]

companies_info = []

for ticker in ticker_symbols:
    try:
        ticker_object = yf.Ticker(ticker)
        info = ticker_object.info
        
        # Find address of company for mapping.
        address1 = info.get("address1")
        city = info.get("city")
        state = info.get("state")
        zip_code = info.get("zip")
        country = info.get("country")
        address = f"{address1}, {city}, {state}, {zip_code}, {country}"
        #companies_address[ticker_symbol] = address
        
        # How large is the company?
        company_name = info.get("longName")
        num_employees = info.get("fullTimeEmployees")
        market_cap = info.get("marketCap")
        enterprise_value = info.get("enterpriseValue")
        total_revenue = info.get("totalRevenue")
        gross_profits = info.get("grossProfits")
        total_debt = info.get("totalDebt")
       
        companies_info.append({
            "Company Name": company_name, 
            "Ticker": ticker, 
            "Address": address,
            "Full Time Employees": num_employees,
            "Market Capitalization (Market Cap)": market_cap,
            "Enterprise Value (EV)": enterprise_value,
            "Total Revenue": total_revenue,
            "Gross Profits": gross_profits,
            "Total Debt": total_debt
        })

    except Exception as e:
        print(f"An error occurred for ticker {ticker}: {e}")

# Convert companies_info to a DataFrame
companies_info_df = pd.DataFrame(companies_info)
companies_info_df
# Out:
#                             Company Name Ticker  \
# 0                Exxon Mobil Corporation    XOM
# 1                    Chevron Corporation    CVX
# 2                              Shell plc   SHEL
# 3                       TotalEnergies SE    TTE
# 4                         ConocoPhillips    COP
# 5                              BP p.l.c.     BP
# 6                            Equinor ASA   EQNR
# 7   Petróleo Brasileiro S.A. - Petrobras    PBR
# 8   Petróleo Brasileiro S.A. - Petrobras  PBR-A
# 9                   Schlumberger Limited    SLB
# 10                   EOG Resources, Inc.    EOG
# 11                         Enbridge Inc.    ENB
# 12    Canadian Natural Resources Limited    CNQ
# 13        Marathon Petroleum Corporation    MPC
# 14     Enterprise Products Partners L.P.    EPD
# 15      Occidental Petroleum Corporation    OXY
# 16     Pioneer Natural Resources Company    PXD
# 17                           Phillips 66    PSX
# 18                            Eni S.p.A.      E
# 19             Valero Energy Corporation    VLO
# 20                      Hess Corporation    HES
# 21             Woodside Energy Group Ltd    WDS
# 22          The Williams Companies, Inc.    WMB
# 23                    Suncor Energy Inc.     SU
# 24                    Energy Transfer LP     ET
# 25                 Cheniere Energy, Inc.    LNG
# 26                   Kinder Morgan, Inc.    KMI
# 27                   Cenovus Energy Inc.    CVE
# 28                   Halliburton Company    HAL
# 29                 TC Energy Corporation    TRP
#
#                                               Address  Full Time Employees  \
# 0   5959 Las Colinas Boulevard, Irving, TX, 75039-...              62000.0
# 1   6001 Bollinger Canyon Road, San Ramon, CA, 945...              43846.0
# 2   Shell Centre, London, None, SE1 7NA, United Ki...              91140.0
# 3   2, place Jean Millier, Courbevoie, None, 92078...             101279.0
# 4   925 North Eldridge Parkway, Houston, TX, 77079...               9700.0
# 5   1 St James's Square, London, None, SW1Y 4PD, U...              67600.0
# 6         Forusbeen 50, Stavanger, None, 4035, Norway              21936.0
# 7   Avenida RepUblica do Chile, 65, Rio De Janeiro...              45149.0
# 8   Avenida RepUblica do Chile, 65, Rio De Janeiro...              45149.0
# 9   5599 San Felipe, Houston, TX, 77056, United St...              99000.0
# 10  1111 Bagby Street, Houston, TX, 77002, United ...               2850.0
# 11  200, Fifth Avenue Place, Calgary, AB, T2P 3L8,...              11100.0
# 12  2100, 855 - 2nd Street S.W., Calgary, AB, T2P ...              10035.0
# 13  539 South Main Street, Findlay, OH, 45840-3229...              17800.0
# 14  1100 Louisiana Street, Houston, TX, 77002-5227...                  NaN
# 15  5 Greenway Plaza, Houston, TX, 77046-0521, Uni...              11973.0
# 16  777 Hidden Ridge, Irving, TX, 75038, United St...               2076.0
# 17  2331 CityWest Boulevard, Houston, TX, 77042, U...              13000.0
# 18   Piazzale Enrico Mattei 1, Rome, RM, 00144, Italy              32188.0
# 19  One Valero Way, San Antonio, TX, 78249, United...               9716.0
# 20  1185 Avenue of the Americas, New York, NY, 100...               1623.0
# 21         Mia Yellagonga, Perth, WA, 6000, Australia               4427.0
# 22  One Williams Center, Tulsa, OK, 74172, United ...               5043.0
# 23       6th Avenue S.W, Calgary, AB, T2P 3E3, Canada              16558.0
# 24  8111 Westchester Drive, Dallas, TX, 75225, Uni...              12565.0
# 25  700 Milam Street, Houston, TX, 77002, United S...               1551.0
# 26  1001 Louisiana Street, Houston, TX, 77002, Uni...              10525.0
# 27  4100, 225 – 6 Avenue SW, Calgary, AB, T2P 0M5,...               5998.0
# 28  3000 North Sam Houston Parkway East, Houston, ...              47000.0
# 29    450 - 1 Street SW, Calgary, AB, T2P 5H1, Canada               7477.0
#
#     Market Capitalization (Market Cap)  Enterprise Value (EV)  Total Revenue  \
# 10                         77394395136            76435587072    25225000960
# 11                         74346250240           162145976320    47503998976
# 12                         67544494080            80517963776    36665999360
# 13                         64392499200            83841646592   157515005952
# 15                         58712489984            85577547776    31536001024
# 16                         55339335680            59893813248    20387000320
# 17                         53521666048            69937381376   154719993856
# 18                         50877345792            65872928768   116525998080
# 19                         50272550912            57497657344   151759994880
# 20                         48415956992            55881506816    10535000064
# 21                         47354826752            48039821312    16817000448
# 22                         43099561984            69459992576    10773999616
# 23                         41542098944            57256005632    56912998400
# 24                         40082350080           102685319168    80754999296
# 25                         40665931776            67407482880    29126000640
# 26                         39616864256            72223776768    17144999936
# 27                         37595660288            47205310464    56027000832
# 28                         36719337472            43270328320    22414000128
# 29                         36738899968            99609001984    15598000128
#
#     Gross Profits    Total Debt
# 0    133715000000   41495998464
# 1     98886000000   21514000384
# 2     97308000000   84366000128
# 3     92261000000   56412000256
# 4     39598000000   16444000256
# 5     70171000000   60699000832
# 6     85590000000   30595000320
# 7    334100000000  279374987264
# 8    334100000000  279374987264
# 9      5161000000   13489999872
# 10    20132000000    4148999936
# 11    20720000000   79474999296
# 12    23613000000   13678999552
# 13    26565000000   28565000192
# 15    24571000000   20686999552
# 16    13262000000    5709000192
# 17    20058000000   19865999360
# 18    31158000000   33462999040
# 19    19224000000   11322999808
# 20     7741000000    9267000320
# 21    10277000000    6771999744
# 22     6078000000   24408999936
# 23    35890000000   16842000384
# 24    13418000000   48961998848
# 25     5977000000   28152000512
# 26     7290000000   31778000896
# 27    15997000000   11308000256
# 28     3243000000    9075999744
# 29     9612000000   61780000768

# %% [markdown]
# # the location of the companies

# %%
# Find latitude and longitude of company from geoapify.com

for index, company in companies_info_df_cleaned.iterrows():
    company_address = company["Address"]
    #company_address = '5959 Las Colinas Boulevard, Irving, TX, 75039-2298, United States'
    url = f"https://api.geoapify.com/v1/geocode/search?text={company_address}&apiKey={geoapify_key}"
    try:
        # Send the API request
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors (e.g., 404)

        data = response.json()

        # Extract latitude and longitude
        if "features" in data and data["features"]:
            latitude = data["features"][0]["properties"]["lat"]
            longitude =data["features"][0]["properties"]["lon"]
            #print(f"Latitude: {latitude}, Longitude: {longitude}")
            companies_info_df_cleaned.loc[index, ["Latitude", "Longitude"]] = [latitude, longitude]
        else:
            print("Company not found or error in API response.")
         
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
    except KeyError:
        print("Error parsing API response.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
# %%capture --no-display
map_plot_1 = companies_info_df_cleaned.hvplot.points(
"Longitude",
"Latitude",
geo=True,
tiles="OSM",
frame_width = 800,
frame_height = 600,
size = "Gross Profits",
scale = 0.0001,
color = "Company Name"
)
# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (Company Name,Gross Profits)

# %% [markdown]
# # 6 Leading Companies By Total Profit In US And UK

# %%
filtered_df = companies_info_df_cleaned[
    companies_info_df_cleaned['Address'].str.contains("United States|United Kingdom")
]
# Sort the DataFrame by "Full Time Employees" in descending order
sorted_df = filtered_df.sort_values(by="Gross Profits", ascending=False)

# Select the top 6 companies
top_companies_profit = sorted_df.head(6)
top_companies_profit
# Out:
#                       Company Name Ticker  \
# 0          Exxon Mobil Corporation    XOM
# 1              Chevron Corporation    CVX
# 2                        Shell plc   SHEL
# 5                        BP p.l.c.     BP
# 4                   ConocoPhillips    COP
# 13  Marathon Petroleum Corporation    MPC
#
#                                               Address  Full Time Employees  \
# 0   5959 Las Colinas Boulevard, Irving, TX, 75039-...              62000.0
# 1   6001 Bollinger Canyon Road, San Ramon, CA, 945...              43846.0
# 2   Shell Centre, London, None, SE1 7NA, United Ki...              91140.0
# 5   1 St James's Square, London, None, SW1Y 4PD, U...              67600.0
# 4   925 North Eldridge Parkway, Houston, TX, 77079...               9700.0
# 13  539 South Main Street, Findlay, OH, 45840-3229...              17800.0
#
#     Market Capitalization (Market Cap)  Enterprise Value (EV)  Total Revenue  \
# 0                         452126474240           460750585856   367977005056
# 1                         306870190080           313186058240   214671998976
# 2                         209383505920           250774175744   358589005824
# 5                         107130331136           479799443456   227586998272
# 4                         142557167616           150705373184    68775002112
# 13                         64392499200            83841646592   157515005952
#
#     Gross Profits   Total Debt   Latitude   Longitude
# 0    133715000000  41495998464  32.890255  -96.949441
# 1     98886000000  21514000384  37.758335 -121.959458
# 2     97308000000  84366000128  51.463735   -0.021389
# 5     70171000000  60699000832  51.507730   -0.134570
# 4     39598000000  16444000256  29.783352  -95.617801
# 13    26565000000  28565000192  41.036497  -83.650163

# %%
# %%capture --no-display
map_plot_2 = top_companies_profit.hvplot.points(
"Longitude",
"Latitude",
geo=True,
tiles="OSM",
frame_width = 800,
frame_height = 600,
size = "Gross Profits",
scale = 0.0002,
color = "Company Name"
)
# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (Company Name,Gross Profits)

# %% [markdown]
# # stock informations for the 6 companies

# %%
# using yfinance
companyList = top_companies_profit["Ticker"]
#xom.history(period="max").tail()
ticker_string = " ".join(companyList)
stock_data = {}
for companyName in companyList:
    # Download data for each company
    companyDataFrame = yf.download(companyName, start="2017-08-01", end="2023-08-01")
    
    # Download data for specific tickers within a date range
    data_range = yf.download(ticker_string, start="2020-01-01", end="2020-06-01")
    
    # Store the closing prices for the company in the dictionary
    stock_data[companyName] = companyDataFrame['Close'].resample('M').last()

# Convert the dictionary to a DataFrame
data = pd.DataFrame(stock_data)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  6 of 6 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  6 of 6 completed
#                    XOM         CVX       SHEL         BP         COP  \
# Date
# 2017-08-31   76.330002  107.620003  55.180000  34.730000   43.660000
# 2017-09-30   81.980003  117.500000  60.580002  38.430000   50.049999
# 2017-10-31   83.349998  115.889999  63.029999  40.669998   51.150002
# 2017-11-30   83.290001  118.989998  64.120003  40.070000   50.880001
# 2017-12-31   83.639999  125.190002  66.709999  42.029999   54.889999
# ...                ...         ...        ...        ...         ...
# 2023-03-31  109.660004  163.160004  57.540001  37.939999   99.209999
# 2023-04-30  118.339996  168.580002  61.980000  40.279999  102.889999
# 2023-05-31  102.180000  150.619995  56.000000  33.709999   99.300003
# 2023-06-30  107.250000  157.350006  60.380001  35.290001  103.610001
# 2023-07-31  107.239998  163.660004  61.630001  37.299999  117.720001
#
#                    MPC
# Date
# 2017-08-31   52.450001
# 2017-09-30   56.080002
# 2017-10-31   59.740002
# 2017-11-30   62.630001
# 2017-12-31   65.980003
# ...                ...
# 2023-03-31  134.830002
# 2023-04-30  122.000000
# 2023-05-31  104.910004
# 2023-06-30  116.599998
# 2023-07-31  133.020004
#
# [72 rows x 6 columns]

# %%
data.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # the line regression between oil price and oil company's stock price

# %%
# oil price in the US from FRED (https://fred.stlouisfed.org/)
csv_file_path_3 = 'Resources/OPEC-ORB.csv'

oil_price_data = pd.read_csv(csv_file_path_3)
oil_price_data
# Out:
#             Date  Value
# 0     2023-08-04  87.95
# 1     2023-08-03  85.47
# 2     2023-08-02  86.66
# 3     2023-08-01  86.60
# 4     2023-07-31  86.45
# ...          ...    ...
# 5308  2003-01-08  28.86
# 5309  2003-01-07  29.72
# 5310  2003-01-06  30.71
# 5311  2003-01-03  30.83
# 5312  2003-01-02  30.05
#
# [5313 rows x 2 columns]

# %%
# clean oil data by month
oil_price_data['Date'] = pd.to_datetime(oil_price_data['Date'])

# Filter the data to include only the desired date range
start_date = "2017-08-01"
end_date = "2023-08-01"
filtered_data = oil_price_data[(oil_price_data['Date'] >= start_date) & (oil_price_data['Date'] <= end_date)]


# Set 'Date' as the index
filtered_data.set_index('Date', inplace=True)

# Resample to get the last date of each month
resampled_data = filtered_data.resample('M').last()


# Plot the resampled data
#plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
#plt.plot(resampled_data.index, resampled_data['Value'], label='Oil Prices (Last Day of Month)')
#plt.show()

# %%
resampled_data
# Out:
#             Value
# Date
# 2017-08-31  49.36
# 2017-09-30  55.20
# 2017-10-31  58.53
# 2017-11-30  61.06
# 2017-12-31  64.47
# ...           ...
# 2023-04-30  79.98
# 2023-05-31  73.07
# 2023-06-30  76.14
# 2023-07-31  86.45
# 2023-08-31  86.60
#
# [73 rows x 1 columns]

# %%
#resampled_data.drop(resampled_data[-1], axis=1, inplace=True)
last_row_index = resampled_data.index[-1]

# Delete the last row
resampled_data.drop(last_row_index, inplace=True)
resampled_data
# Out:
#             Value
# Date
# 2017-08-31  49.36
# 2017-09-30  55.20
# 2017-10-31  58.53
# 2017-11-30  61.06
# 2017-12-31  64.47
# ...           ...
# 2023-03-31  78.12
# 2023-04-30  79.98
# 2023-05-31  73.07
# 2023-06-30  76.14
# 2023-07-31  86.45
#
# [72 rows x 1 columns]

# %%
data
# Out:
#                    XOM         CVX       SHEL         BP         COP  \
# Date
# 2017-08-31   76.330002  107.620003  55.180000  34.730000   43.660000
# 2017-09-30   81.980003  117.500000  60.580002  38.430000   50.049999
# 2017-10-31   83.349998  115.889999  63.029999  40.669998   51.150002
# 2017-11-30   83.290001  118.989998  64.120003  40.070000   50.880001
# 2017-12-31   83.639999  125.190002  66.709999  42.029999   54.889999
# ...                ...         ...        ...        ...         ...
# 2023-03-31  109.660004  163.160004  57.540001  37.939999   99.209999
# 2023-04-30  118.339996  168.580002  61.980000  40.279999  102.889999
# 2023-05-31  102.180000  150.619995  56.000000  33.709999   99.300003
# 2023-06-30  107.250000  157.350006  60.380001  35.290001  103.610001
# 2023-07-31  107.239998  163.660004  61.630001  37.299999  117.720001
#
#                    MPC
# Date
# 2017-08-31   52.450001
# 2017-09-30   56.080002
# 2017-10-31   59.740002
# 2017-11-30   62.630001
# 2017-12-31   65.980003
# ...                ...
# 2023-03-31  134.830002
# 2023-04-30  122.000000
# 2023-05-31  104.910004
# 2023-06-30  116.599998
# 2023-07-31  133.020004
#
# [72 rows x 6 columns]

# %%
plt.plot(data.index, data["XOM"])
plt.plot(resampled_data.index, resampled_data['Value'])
plt.show()

# %%
# line regression function
def linear_reg_plt(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-",label="_nolegend_")
    return rvalue, line_eq

# %% [markdown]
# ### oil price vs.  Exxon Mobil Corporation (XOM)

# %%
x_values = resampled_data["Value"]
y_values = data["XOM"]
rvalue, line_eq = linear_reg_plt(x_values,y_values)
#plt.title('Northern Hemisphere')
#plt.xlabel('Latitude')
#plt.ylabel('Max Temp')
print(f"The r-value is: {round(rvalue,2)}")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.67

# %% [markdown]
# ### oil price vs.  Chevron Corporation (CVX)

# %%
x_values = resampled_data["Value"]
y_values = data["CVX"]
rvalue, line_eq = linear_reg_plt(x_values,y_values)
#plt.title('Northern Hemisphere')
#plt.xlabel('Latitude')
#plt.ylabel('Max Temp')
print(f"The r-value is: {round(rvalue,2)}")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.79

# %% [markdown]
# ### oil price vs. Shell plc (SHEL)

# %%
x_values = resampled_data["Value"]
y_values = data["SHEL"]
rvalue, line_eq = linear_reg_plt(x_values,y_values)
#plt.title('Northern Hemisphere')
#plt.xlabel('Latitude')
#plt.ylabel('Max Temp')
print(f"The r-value is: {round(rvalue,2)}")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.44

# %% [markdown]
# ### oil price vs. BP p.l.c. (BP)

# %%
x_values = resampled_data["Value"]
y_values = data["BP"]
rvalue, line_eq = linear_reg_plt(x_values,y_values)
#plt.title('Northern Hemisphere')
#plt.xlabel('Latitude')
#plt.ylabel('Max Temp')
print(f"The r-value is: {round(rvalue,2)}")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.23

# %% [markdown]
# ### oil price vs. ConocoPhillips (COP)

# %%
x_values = resampled_data["Value"]
y_values = data["COP"]
rvalue, line_eq = linear_reg_plt(x_values,y_values)
#plt.title('Northern Hemisphere')
#plt.xlabel('Latitude')
#plt.ylabel('Max Temp')
print(f"The r-value is: {round(rvalue,2)}")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.81

# %% [markdown]
# ### oil price vs. Marathon Petroleum Corporation (MPC)

# %%
x_values = resampled_data["Value"]
y_values = data["MPC"]
rvalue, line_eq = linear_reg_plt(x_values,y_values)
#plt.title('Northern Hemisphere')
#plt.xlabel('Latitude')
#plt.ylabel('Max Temp')
print(f"The r-value is: {round(rvalue,2)}")
plt.annotate(line_eq,(10,5),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.72
